# %% [markdown]
# <a href="https://colab.research.google.com/github/ryurikritz/ProjectAIMLYear1May2026/blob/main/Boosting_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier

df = pd.read_csv('data.csv')
# Prepare features and target
features = [
    'months_loan_duration',
    'amount',
    'percent_of_income',
    'years_at_residence',
    'age',
    'existing_loans_count',
    'dependents'
]
X = df[features]
y= df['default']

# Replace 'no' with 0 and 'yes' with 1 in y
y = y.replace({'no':0, 'yes':1})
# Split the dataset
# A 70:30 ratio means test size is 0.3
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=1)

# Build and train the model
model = AdaBoostClassifier(random_state=1)
model.fit(X_train, y_train)

#Evaluate the model
test_score = model.score(X_test, y_test)
print(f"Test score: {test_score}")
